# %%
from pycalphad import Database, equilibrium
from pycalphad.variables import T, P, X
import dask
dbf_string = """
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
$ Date: 2017-05-08 09:03
$ Components: AL, NI, VA
$ Phases: AL3NI1, AL3NI2, AL3NI5, BCC_B2, FCC_L12, LIQUID
$ Generated by rotis (pycalphad 0.5+3.gf80ed4d.dirty)
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

ELEMENT AL BLANK 0 0 0 !
ELEMENT NI BLANK 0 0 0 !
ELEMENT VA BLANK 0 0 0 !

FUNCTION GBCCAL 298.15 -4.813*T + GHSERAL# + 10083; 2900.0 N !
FUNCTION GBCCNI 298.15 -3.556*T + GHSERNI# + 8715.084; 3000.0 N !
FUNCTION GFCCAL 298.15 GHSERAL#; 2900.0 N !
FUNCTION GFCCNI 298.15 GHSERNI#; 3000.0 N !
FUNCTION GHSERAL 298.15 -8.77664E-7*T**3 - 0.001884662*T**2 -
   24.3671976*T*LN(T) + 137.093038*T - 7976.15 + 74092*T**(-1); 700.0 Y
   -5.764227E-6*T**3 + 0.018531982*T**2 - 38.5844296*T*LN(T) + 223.048446*T -
   11276.24 + 74092*T**(-1); 933.47 Y -31.748192*T*LN(T) + 188.684153*T -
   11278.378 - 1.230524E+28*T**(-9); 2900.0 N !
FUNCTION GHSERNI 298.15 -0.0048407*T**2 - 22.096*T*LN(T) + 117.854*T -
   5179.159; 1728.0 Y -43.1*T*LN(T) + 279.135*T - 27840.655 +
   1.12754E+31*T**(-9); 3000.0 N !
FUNCTION GHSERVA 1 0; 10000 N !
FUNCTION GLIQAL 298.15 7.9337E-20*T**7 - 11.841867*T + GHSERAL# + 11005.029;
   700.0 Y 7.9337E-20*T**7 - 11.841867*T + GHSERAL# + 11005.03; 933.47 Y
   -31.748192*T*LN(T) + 177.430178*T - 795.996; 2900.0 N !
FUNCTION GLIQNI 298.15 -3.82318E-21*T**7 - 9.397*T + GHSERNI# + 16414.686;
   1728.0 Y -43.1*T*LN(T) + 268.598*T - 9549.775; 3000.0 N !

TYPE_DEFINITION % SEQ * !
DEFINE_SYSTEM_DEFAULT ELEMENT 2 !
DEFAULT_COMMAND DEFINE_SYSTEM_ELEMENT VA !

PHASE AL3NI1 %  2 0.75 0.25 !
CONSTITUENT AL3NI1 :AL:NI: !

PHASE AL3NI2 %  3 2 1 2 !
CONSTITUENT AL3NI2 :AL,NI:AL,NI:NI,VA: !

PHASE AL3NI5 %  2 0.375 0.625 !
CONSTITUENT AL3NI5 :AL:NI: !

PHASE BCC_B2 %  3 0.5 0.5 1 !
CONSTITUENT BCC_B2 :AL,NI,VA:AL,NI,VA:VA: !

PHASE FCC_L12 %  5 0.25 0.25 0.25 0.25 1 !
CONSTITUENT FCC_L12 :AL,NI:AL,NI:AL,NI:AL,NI:VA: !

PHASE LIQUID %  1 1 !
CONSTITUENT LIQUID :AL,NI: !



$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
$                                     AL                                     $
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

PARAMETER G(AL3NI2,AL:AL:VA;0) 1 T*VV0005# + 3*GHSERAL# + VV0004#; 10000 N !
PARAMETER G(BCC_B2,AL:AL:VA;0) 1 1.0*GBCCAL#; 10000 N !
PARAMETER G(BCC_B2,AL:VA:VA;0) 1 T*VV0031# + 0.5*GHSERAL# + VV0030#; 10000 N !
PARAMETER G(BCC_B2,VA:AL:VA;0) 1 T*VV0031# + 0.5*GHSERAL# + VV0030#; 10000 N !
PARAMETER L(BCC_B2,AL,VA:VA:VA;0) 1 VV0038#; 10000 N !
PARAMETER L(BCC_B2,VA:AL,VA:VA;0) 1 VV0038#; 10000 N !
PARAMETER G(FCC_L12,AL:AL:AL:AL:VA;0) 1 1.0*GFCCAL#; 10000 N !
PARAMETER G(LIQUID,AL;0) 1 GLIQAL#; 10000 N !


$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
$                                     NI                                     $
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

PARAMETER G(AL3NI2,NI:NI:NI;0) 1 5*GHSERNI#; 10000 N !
PARAMETER G(AL3NI2,NI:NI:VA;0) 1 3*GHSERNI#; 10000 N !
PARAMETER G(BCC_B2,NI:NI:VA;0) 1 1.0*GBCCNI#; 10000 N !
PARAMETER G(BCC_B2,NI:VA:VA;0) 1 0.5*GHSERNI# + VV0032#; 10000 N !
PARAMETER G(BCC_B2,VA:NI:VA;0) 1 0.5*GHSERNI# + VV0032#; 10000 N !
PARAMETER L(BCC_B2,NI,VA:VA:VA;0) 1 VV0039#; 10000 N !
PARAMETER L(BCC_B2,VA:NI,VA:VA;0) 1 VV0039#; 10000 N !
PARAMETER G(FCC_L12,NI:NI:NI:NI:VA;0) 1 1.0*GFCCNI#; 10000 N !
PARAMETER G(LIQUID,NI;0) 1 GLIQNI#; 10000 N !


$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
$                                     VA                                     $
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

PARAMETER G(BCC_B2,VA:VA:VA;0) 1 0; 10000 N !


$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
$                                   AL-NI                                    $
$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

PARAMETER G(AL3NI1,AL:NI;0) 1 T*VV0001# + 0.75*GHSERAL# + 0.25*GHSERNI# +
   VV0000#; 10000 N !
PARAMETER G(AL3NI2,AL:AL:NI;0) 1 T*VV0003# + 3*GHSERAL# + 2*GHSERNI# +
   VV0002#; 10000 N !
PARAMETER G(AL3NI2,AL:NI:NI;0) 1 T*VV0007# + 2*GHSERAL# + 3*GHSERNI# +
   VV0006#; 10000 N !
PARAMETER G(AL3NI2,AL:NI:VA;0) 1 T*VV0009# + 2*GHSERAL# + GHSERNI# + VV0008#;
   10000 N !
PARAMETER G(AL3NI2,NI:AL:NI;0) 1 GHSERAL# + 4*GHSERNI#; 10000 N !
PARAMETER G(AL3NI2,NI:AL:VA;0) 1 GHSERAL# + 2*GHSERNI#; 10000 N !
PARAMETER L(AL3NI2,AL:AL:NI,VA;0) 1 VV0012#; 10000 N !
PARAMETER L(AL3NI2,AL:AL:NI,VA;1) 1 VV0011#; 10000 N !
PARAMETER L(AL3NI2,AL:AL:NI,VA;2) 1 VV0010#; 10000 N !
PARAMETER L(AL3NI2,AL:AL,NI:NI;0) 1 VV0015#; 10000 N !
PARAMETER L(AL3NI2,AL:AL,NI:NI;1) 1 VV0014#; 10000 N !
PARAMETER L(AL3NI2,AL:AL,NI:NI;2) 1 VV0013#; 10000 N !
PARAMETER L(AL3NI2,AL:AL,NI:VA;0) 1 VV0018#; 10000 N !
PARAMETER L(AL3NI2,AL:AL,NI:VA;1) 1 VV0017#; 10000 N !
PARAMETER L(AL3NI2,AL:AL,NI:VA;2) 1 VV0016#; 10000 N !
PARAMETER L(AL3NI2,AL:NI:NI,VA;0) 1 VV0021#; 10000 N !
PARAMETER L(AL3NI2,AL:NI:NI,VA;1) 1 VV0020#; 10000 N !
PARAMETER L(AL3NI2,AL:NI:NI,VA;2) 1 VV0019#; 10000 N !
PARAMETER G(AL3NI5,AL:NI;0) 1 T*VV0023# + 0.375*GHSERAL# + 0.625*GHSERNI# +
   VV0022#; 10000 N !
PARAMETER G(BCC_B2,AL:NI:VA;0) 1 T**3*VV0027# + T**2*VV0026# +
   T*VV0028#*LN(T) + T*VV0029# + 0.5*GHSERAL# + 0.5*GHSERNI# + VV0024# +
   VV0025#*T**(-1); 10000 N !
PARAMETER G(BCC_B2,NI:AL:VA;0) 1 T**3*VV0027# + T**2*VV0026# +
   T*VV0028#*LN(T) + T*VV0029# + 0.5*GHSERAL# + 0.5*GHSERNI# + VV0024# +
   VV0025#*T**(-1); 10000 N !
PARAMETER L(BCC_B2,AL:AL,NI:VA;0) 1 VV0033#; 10000 N !
PARAMETER L(BCC_B2,AL:NI,VA:VA;0) 1 VV0034#; 10000 N !
PARAMETER L(BCC_B2,AL,NI:AL:VA;0) 1 VV0033#; 10000 N !
PARAMETER L(BCC_B2,AL,NI:NI:VA;0) 1 VV0035#; 10000 N !
PARAMETER L(BCC_B2,AL,NI:VA:VA;0) 1 VV0036#; 10000 N !
PARAMETER L(BCC_B2,AL,VA:NI:VA;0) 1 VV0037#; 10000 N !
PARAMETER L(BCC_B2,NI:AL,NI:VA;0) 1 VV0035#; 10000 N !
PARAMETER L(BCC_B2,NI:AL,VA:VA;0) 1 VV0037#; 10000 N !
PARAMETER L(BCC_B2,NI,VA:AL:VA;0) 1 VV0034#; 10000 N !
PARAMETER L(BCC_B2,VA:AL,NI:VA;0) 1 VV0036#; 10000 N !
PARAMETER L(BCC_B2,AL,NI:AL,NI:VA;0) 1 VV0040#; 10000 N !
PARAMETER G(FCC_L12,AL:AL:AL:NI:VA;0) 1 T*VV0042# + 0.75*GHSERAL# +
   0.25*GHSERNI# + VV0041#; 10000 N !
PARAMETER G(FCC_L12,AL:AL:NI:AL:VA;0) 1 T*VV0042# + 0.75*GHSERAL# +
   0.25*GHSERNI# + VV0041#; 10000 N !
PARAMETER G(FCC_L12,AL:AL:NI:NI:VA;0) 1 T*VV0044# + 0.5*GHSERAL# +
   0.5*GHSERNI# + VV0043#; 10000 N !
PARAMETER G(FCC_L12,AL:NI:AL:AL:VA;0) 1 T*VV0042# + 0.75*GHSERAL# +
   0.25*GHSERNI# + VV0041#; 10000 N !
PARAMETER G(FCC_L12,AL:NI:NI:AL:VA;0) 1 T*VV0044# + 0.5*GHSERAL# +
   0.5*GHSERNI# + VV0043#; 10000 N !
PARAMETER G(FCC_L12,AL:NI:NI:NI:VA;0) 1 T**3*VV0048# + T**2*VV0047# +
   T*VV0049#*LN(T) + T*VV0050# + 0.25*GHSERAL# + 0.75*GHSERNI# + VV0045# +
   VV0046#*T**(-1); 10000 N !
PARAMETER G(FCC_L12,NI:AL:AL:AL:VA;0) 1 T*VV0042# + 0.75*GHSERAL# +
   0.25*GHSERNI# + VV0041#; 10000 N !
PARAMETER G(FCC_L12,NI:AL:AL:NI:VA;0) 1 T*VV0044# + 0.5*GHSERAL# +
   0.5*GHSERNI# + VV0043#; 10000 N !
PARAMETER G(FCC_L12,NI:AL:NI:NI:VA;0) 1 T**3*VV0048# + T**2*VV0047# +
   T*VV0049#*LN(T) + T*VV0050# + 0.25*GHSERAL# + 0.75*GHSERNI# + VV0045# +
   VV0046#*T**(-1); 10000 N !
PARAMETER G(FCC_L12,NI:NI:AL:AL:VA;0) 1 T*VV0044# + 0.5*GHSERAL# +
   0.5*GHSERNI# + VV0043#; 10000 N !
PARAMETER G(FCC_L12,NI:NI:AL:NI:VA;0) 1 T**3*VV0048# + T**2*VV0047# +
   T*VV0049#*LN(T) + T*VV0050# + 0.25*GHSERAL# + 0.75*GHSERNI# + VV0045# +
   VV0046#*T**(-1); 10000 N !
PARAMETER G(FCC_L12,NI:NI:NI:AL:VA;0) 1 T**3*VV0048# + T**2*VV0047# +
   T*VV0049#*LN(T) + T*VV0050# + 0.25*GHSERAL# + 0.75*GHSERNI# + VV0045# +
   VV0046#*T**(-1); 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL:AL,NI:VA;0) 1 VV0053#; 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL:AL,NI:VA;1) 1 VV0052#; 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL:AL,NI:VA;2) 1 VV0051#; 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL,NI:AL:VA;0) 1 VV0053#; 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL,NI:AL:VA;1) 1 VV0052#; 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL,NI:AL:VA;2) 1 VV0051#; 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL,NI:NI:VA;0) 1 VV0056#; 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL,NI:NI:VA;1) 1 VV0055#; 10000 N !
PARAMETER L(FCC_L12,AL:AL:AL,NI:NI:VA;2) 1 VV0054#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:AL:AL:VA;0) 1 VV0053#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:AL:AL:VA;1) 1 VV0052#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:AL:AL:VA;2) 1 VV0051#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:NI:AL:VA;0) 1 VV0056#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:NI:AL:VA;1) 1 VV0055#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:NI:AL:VA;2) 1 VV0054#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:NI:NI:VA;0) 1 VV0059#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:NI:NI:VA;1) 1 VV0058#; 10000 N !
PARAMETER L(FCC_L12,AL:AL,NI:NI:NI:VA;2) 1 VV0057#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:AL:AL:AL:VA;0) 1 VV0053#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:AL:AL:AL:VA;1) 1 VV0052#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:AL:AL:AL:VA;2) 1 VV0051#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:AL:AL:VA;0) 1 VV0056#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:AL:AL:VA;1) 1 VV0055#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:AL:AL:VA;2) 1 VV0054#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:NI:AL:VA;0) 1 VV0059#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:NI:AL:VA;1) 1 VV0058#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:NI:AL:VA;2) 1 VV0057#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:NI:NI:VA;0) 1 VV0062#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:NI:NI:VA;1) 1 VV0061#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:NI:NI:NI:VA;2) 1 VV0060#; 10000 N !
PARAMETER L(FCC_L12,NI:AL:AL:AL,NI:VA;0) 1 VV0056#; 10000 N !
PARAMETER L(FCC_L12,NI:AL:AL:AL,NI:VA;1) 1 VV0055#; 10000 N !
PARAMETER L(FCC_L12,NI:AL:AL:AL,NI:VA;2) 1 VV0054#; 10000 N !
PARAMETER L(FCC_L12,NI:AL:AL,NI:NI:VA;0) 1 VV0059#; 10000 N !
PARAMETER L(FCC_L12,NI:AL:AL,NI:NI:VA;1) 1 VV0058#; 10000 N !
PARAMETER L(FCC_L12,NI:AL:AL,NI:NI:VA;2) 1 VV0057#; 10000 N !
PARAMETER L(FCC_L12,NI:AL,NI:NI:NI:VA;0) 1 VV0062#; 10000 N !
PARAMETER L(FCC_L12,NI:AL,NI:NI:NI:VA;1) 1 VV0061#; 10000 N !
PARAMETER L(FCC_L12,NI:AL,NI:NI:NI:VA;2) 1 VV0060#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:AL:AL,NI:VA;0) 1 VV0059#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:AL:AL,NI:VA;1) 1 VV0058#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:AL:AL,NI:VA;2) 1 VV0057#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:AL,NI:NI:VA;0) 1 VV0062#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:AL,NI:NI:VA;1) 1 VV0061#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:AL,NI:NI:VA;2) 1 VV0060#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:NI:AL,NI:VA;0) 1 VV0062#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:NI:AL,NI:VA;1) 1 VV0061#; 10000 N !
PARAMETER L(FCC_L12,NI:NI:NI:AL,NI:VA;2) 1 VV0060#; 10000 N !
PARAMETER L(FCC_L12,AL,NI:AL,NI:AL,NI:AL,NI:VA;0) 1 VV0063#; 10000 N !
PARAMETER L(LIQUID,AL,NI;0) 1 VV0066#; 10000 N !
PARAMETER L(LIQUID,AL,NI;1) 1 VV0065#; 10000 N !
PARAMETER L(LIQUID,AL,NI;2) 1 VV0064#; 10000 N !

"""
dbf = Database(dbf_string)
comps = ['VA', 'AL', 'NI']
phases = ['LIQUID']
from pycalphad import variables as v
from pycalphad import calculate
from pycalphad import CompiledModel
phases = ['FCC_L12']
cond_dict = {v.T: 1645.0, v.P: 101325.0, v.X('NI'): 0.761}
parameters = {'VV0032': 32790.6, 'VV0020': -2634.67, 'VV0049': 1.13542, 'VV0022': -55383.5, 'VV0060': -1704.0, 'VV0007': 50.5575, 'VV0054': 32.0, 'VV0011': -2634.67, 'VV0004': 15000.0, 'VV0056': 3768.0, 'VV0001': 1.7270843721843232, 'VV0015': -33080.0, 'VV0055': 2752.0, 'VV0066': -197437.0, 'VV0040': -152236.0, 'VV0042': 0.55316, 'VV0039': 34418.8, 'VV0009': 33.312, 'VV0041': -21524.2, 'VV0019': 245.333, 'VV0057': 2522.67, 'VV0021': -16480.0, 'VV0027': 9.52839e-08, 'VV0008': -179176.0, 'VV0053': 5512.0, 'VV0062': 5122.0, 'VV0064': 61412.5, 'VV0065': 14423.4, 'VV0046': -6040.3, 'VV0025': 23095.2, 'VV0031': 10.0, 'VV0038': 67135.0, 'VV0026': 0.00123463, 'VV0030': 16432.5, 'VV0037': 41335.6, 'VV0045': -41810.9, 'VV0047': -0.000436214, 'VV0043': -53132.68190383372, 'VV0002': -27355.0, 'VV0017': 9.53904e-12, 'VV0034': -28577.7, 'VV0028': 0.000871897, 'VV0050': -5.83812, 'VV0013': -53.3333, 'VV0006': -297040.0, 'VV0010': 245.333, 'VV0036': -150055.0, 'VV0000': -39656.1, 'VV0029': 1.31471, 'VV0059': -5196.0, 'VV0018': -23820.0, 'VV0003': 1.93935, 'VV0061': 1226.67, 'VV0012': -16480.0, 'VV0058': 3125.33, 'VV0016': -16.0, 'VV0033': 45262.9, 'VV0052': -533.333, 'VV0051': -1952.0, 'VV0023': 5.392, 'VV0063': -4257290.0, 'VV0024': -64435.3, 'VV0048': 3.13447e-07, 'VV0035': -20275.1, 'VV0005': -1.5, 'VV0014': 1.04734e-11, 'VV0044': 0.8813492854915976}
#dbf.symbols.update(parameters)
equilibrium(dbf, comps, phases, cond_dict, parameters=parameters, verbose=True)
res = calculate(dbf, comps, phases, T=1645, P=101325, parameters=parameters)
# Out:
# Calculation Backend: Compiled (autowrap)
# Components: AL NI VA
# Phases: FCC_L12 [done]
# ('NEW_L_MULTIPLIERS', array([  14153.05727799,   14105.00531534,   14104.98166325,
#           9298.08262898,   15949.51690172, -113385.34834597,
#        -113385.14762129,  -80375.69546641, -113385.24798482,
#        -129793.04343648, -220484.81226102,  -99296.88046398]))
# ('old_driving_force', -128355.24228460711)
# (1.0, -128298.00311448656, 0.0025902370908601757)
# (0.5, -128318.73379653947, 0.00023627102770340525)
# (0.25, -128334.25010374936, 5.9067756131070404e-05)
# (0.125, -128344.07527040954, 1.4766938729260382e-05)
# (0.0625, -128349.49657806408, 3.6917345729303719e-06)
# (0.03125, -128352.32979288409, 9.2293363251894078e-07)
# (0.015625, -128353.77625638271, 2.3073343091706278e-07)
# (0.0078125, -128354.50684164153, 5.768335775702127e-08)
# ('alpha', 0.0078125)
# ('Phases', [CompositionSet(FCC_L12, [ 0.25012163  0.74987837]), CompositionSet(FCC_L12, [ 0.22756534  0.77243466])])
# ...
